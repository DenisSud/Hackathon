# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("ecology_renamed.xlsx")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_excel("ecology_renamed.xlsx")
#       2 df
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
column_names = df.columns

for i in column_names:
    print(i)
# Out:
# Unnamed: 0
# id
# Отрасль экономики, к которой относится фирма
# Размер фирмы
# Федеральный округ, в котором проводился опрос фирмы
# Вид услуг, оказываемых фирмой
# Организационно-правовая форма фирмы
# В каком году фирма начала деятельность
#  Руководителем фирмы является женщина?
# Основной товар/услуга (по наибольшему % от годовых продаж) в прошлом финансовом году
# Процент земельных владений фирмы, находящихся в собственности (остальные арендованы)
# В какой степени экологическое регулирование является препятствием в текущей деятельности?
# Позиция, которую занимает экологическое регулирование, среди других предложенных вариантов возможных препятствий для осуществления деятельности
# На ближайшие З года, какие государственные расходы должны иметь наивысший приоритет?
# Суммарные затраты на трудовые ресурсы (включая зарплаты, бонусы сотрудникам и тд) за прошлый финансовый год
# Затраты на сырьё и материалы, использованные для производства в прошлом финансовом году
# ...

# %%
replacements = {"Да": 1, "Нет": 0}
df = df.replace(replacements)

df.to_excel("updated_data.xlsx", index=False, engine='openpyxl')

print("Данные успешно обновлены и сохранены в 'updated_data.xlsx'.")
# Out:
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 1318   -1
# 1319   -1
# 1320   -1
# 1321   -1
# 1322   -1
# Name: Unnamed: 0, Length: 1323, dtype: int64
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 1318   -1
# 1319   -1
# 1320   -1
# 1321   -1
# 1322   -1
# Name: id, Length: 1323, dtype: int64
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 1318   -1
# 1319   -1
# 1320   -1
# 1321   -1
# 1322   -1
# Name: Отрасль экономики, к которой относится фирма, Length: 1323, dtype: int64
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 1318   -1
# 1319   -1
# 1320   -1
# 1321   -1
# 1322   -1
# Name: Размер фирмы, Length: 1323, dtype: int64
# 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 1318   -1
# 1319   -1
# 1320   -1
# 1321   -1
# 1322   -1
# Name: Федеральный округ, в котором проводился опрос фирмы, Length: 1323, dtype: int64
# 0      -1
# 1      -1
# 2      -1
# ...

# %%
df = pd.read_excel("new_dataset.xlsx")

df.drop("Unnamed: 0", axis=1)
# print(df["В какой степени экологическое регулирование является препятствием в текущей деятельности?"].unique())

mapping = {
    'Не является препятствием': 0,
    'Незначительное препятствие': 0.25,
    'Среднее препятствие': 0.5,
    'Серьезное препятствие': 0.75,
    'Очень серьезное препятствие': 1,
    'Не знаю': -1,
    'Не применимо': -1,
}

# Map the values and replace them in the DataFrame
df["В какой степени экологическое регулирование является препятствием в текущей деятельности?"].map(mapping)
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  id Отрасль экономики, к которой относится фирма  \
# 0             0           0  22                Готовые Металлические Изделия
# 1             1           1  29                        Машины и оборудование
# 2             2           2  34                          Другое Производство
# 3             3           3  50                Готовые Металлические Изделия
# 4             4           4  56                                Другие Услуги
#
#   Размер фирмы Федеральный округ, в котором проводился опрос фирмы  \
# 0        Малый                      Центральный Федеральный округ
# 1      Крупный                      Центральный Федеральный округ
# 2      Средний                      Центральный Федеральный округ
# 3        Малый                      Центральный Федеральный округ
# 4        Малый                      Центральный Федеральный округ
#
#   Вид услуг, оказываемых фирмой В каком году фирма начала деятельность  \
# ...
